# %% [markdown]
# # Seaborn Examples
# This notebook contains examples used in the workshop that utilize Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# See what's availabke
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# Let's look at some penguins
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
g = sns.catplot(x="species", y="body_mass_g", hue="sex", col="island",
               data=df, kind="bar", aspect=0.5, errorbar=('ci',95))
g.set_axis_labels("Species", "Body mass (g)")
g.set_titles("{col_name} {col_var}")
g.fig.suptitle('Body mass of different species of penguin on different islands')
plt.tight_layout()
# Out:
# /opt/anaconda3/envs/jupyter/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /var/folders/w0/nm0yn6ss1xlfx68xtmqvv0d00000gn/T/ipykernel_59296/1700123054.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# Histograms
h = sns.histplot(df, x='flipper_length_mm', hue='species', element='step')
h.set(xlabel='Flipper Length (mm)', ylabel='Count', title='Penguin flipper length distribution by species')

plt.show()

# %%
f = sns.scatterplot(data=sns.load_dataset('flights'), x='year', y='passengers', hue='month')
f.set(xlabel='Year', ylabel='Passengers', title='Passengers by year and month')
plt.savefig('viz/flights.png')
