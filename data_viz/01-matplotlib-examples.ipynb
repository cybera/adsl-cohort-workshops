# %% [markdown]
# # Matplotlib Examples
#
# This notebook is used for the creation of matplotlib examples used in the ADSL Data Viz workshop. Feel free to refer to these or modify the code if it helps with learning

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from zipfile import ZipFile
from io import BytesIO
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ### Single Plot

# %%
# Example taken from matplotlib website:
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html#sphx-glr-gallery-lines-bars-and-markers-simple-plot-py

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %% [markdown]
# ### Subplots

# %%
# Subplots example
# Example taken from matplotlib website:
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/categorical_variables.html#sphx-glr-gallery-lines-bars-and-markers-categorical-variables-py

data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# ### Box plots

# %%
r = requests.get("https://archive.ics.uci.edu/static/public/53/iris.zip")
files = ZipFile(BytesIO(r.content))
names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]
iris = pd.read_csv(files.open("iris.data"), names=names)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
plt.boxplot([iris["sepal_length"], iris["sepal_width"], iris["petal_length"], iris["petal_width"]])
plt.ylabel("Length / width (cm)")
plt.xticks([1, 2, 3, 4], ["Sepal length", "Sepal width", "Petal length", "Petal width"])
plt.title('Distribution of petal features')


plt.show()

# %% [markdown]
# ### Multiple dimensions

# %%
bb = pd.read_csv('https://github.com/callysto/data-files/raw/main/data-viz-of-the-week/baseball/data/darvish-pitches.csv')
bb.head()
# Out:
# /var/folders/w0/nm0yn6ss1xlfx68xtmqvv0d00000gn/T/ipykernel_59257/1656645808.py:1: DtypeWarning: Columns (87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   bb = pd.read_csv('https://github.com/callysto/data-files/raw/main/data-viz-of-the-week/baseball/data/darvish-pitches.csv')
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2019-04-04           93.1        -2.7528         5.2611
# 1         FF  2019-04-04           92.6        -2.7149         5.2909
# 2         FF  2019-04-04           91.6        -2.6875         5.3133
# 3         FF  2019-04-04           92.4        -2.6839         5.3665
# 4         FF  2019-04-04           92.1        -2.6652         5.3911
#
#   player_name  batter  pitcher events      description  ...  home_score  \
# 0  Yu Darvish  518626   506433   walk             ball  ...           1
# 1  Yu Darvish  518626   506433    NaN             ball  ...           1
# 2  Yu Darvish  518626   506433    NaN  swinging_strike  ...           1
# 3  Yu Darvish  518626   506433    NaN     blocked_ball  ...           1
# 4  Yu Darvish  518626   506433    NaN             ball  ...           1
#
#    away_score  bat_score  fld_score  post_away_score post_home_score  \
# 0           0          1          0                0               1
# 1           0          1          0                0               1
# 2           0          1          0                0               1
# 3           0          1          0                0               1
# 4           0          1          0                0               1
#
#   post_bat_score post_fld_score if_fielding_alignment of_fielding_alignment
# 0              1              0              Standard              Standard
# 1              1              0              Standard              Standard
# 2              1              0              Standard              Standard
# 3              1              0              Standard              Standard
# 4              1              0              Standard              Standard
#
# [5 rows x 89 columns]

# %%
plt.scatter(bb['game_date'], bb['release_speed'])
